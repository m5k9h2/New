# %%
import pandas as pd

from io import StringIO

# %%
df = pd.read_csv("listings.csv")

# %%
df.head()
# Out:
#        id                                               name  host_id  \
# 0   50904  Boutique hotel in Antwerp · ★5.0 · 1 bedroom ·...   234077
# 1  224682  Rental unit in Antwerpen · ★4.79 · 1 bedroom ·...  1263933
# 2  345959  Rental unit in Antwerp · ★4.81 · 2 bedrooms · ...  1754396
# 3  363155  Rental unit in Antwerp · ★4.86 · 1 bedroom · 1...  1835458
# 4  366252  Rental unit in Antwerp · ★4.64 · 1 bedroom · 1...  1820186
#
#    host_name  neighbourhood_group                 neighbourhood   latitude  \
# 0      Karin                  NaN            Historisch Centrum  51.218575
# 1   Kristien                  NaN            Historisch Centrum  51.219060
# 2    Marleen                  NaN                     Markgrave  51.201500
# 3       Roos                  NaN            Amandus - Atheneum  51.221090
# 4  Godelieve                  NaN  Borgerhout Intra Muros Noord  51.216020
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df.tail()
# Out:
#                       id                                               name  \
# 2697  985884685168980132  Rental unit in Antwerpen · ★New · 2 bedrooms ·...
# 2698  985890098771633134  Rental unit in Antwerpen · ★New · 2 bedrooms ·...
# 2699  985916294990138848  Guesthouse in Antwerpen · ★New · 1 bedroom · 1...
# 2700  985961461326277025  Rental unit in Antwerpen · ★New · 2 bedrooms ·...
# 2701  985971781886468372  Rental unit in Antwerpen · ★New · 2 bedrooms ·...
#
#         host_id host_name  neighbourhood_group       neighbourhood   latitude  \
# 2697  165436938      Luca                  NaN  Universiteitsbuurt  51.220761
# 2698  165436938      Luca                  NaN  Universiteitsbuurt  51.220761
# 2699   46395835      Kris                  NaN  Universiteitsbuurt  51.224471
# 2700  317037207     Elisa                  NaN  Universiteitsbuurt  51.220761
# 2701  165436938      Luca                  NaN  Universiteitsbuurt  51.220761
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2702, step=1)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df.to_numpy()
# Out:
# array([[50904,
#         'Boutique hotel in Antwerp · ★5.0 · 1 bedroom · 1 bed · 1 private bath',
#         234077, ..., 241, 0, nan],
#        [224682,
#         'Rental unit in Antwerpen · ★4.79 · 1 bedroom · 2 beds · 1 bath',
#         1263933, ..., 331, 99, nan],
#        [345959,
#         'Rental unit in Antwerp · ★4.81 · 2 bedrooms · 2 beds · 1 bath',
#         1754396, ..., 319, 15, nan],
#        ...,
#        [985916294990138848,
#         'Guesthouse in Antwerpen · ★New · 1 bedroom · 1 bed · 1 shared bath',
#         46395835, ..., 83, 0, nan],
#        [985961461326277025,
#         'Rental unit in Antwerpen · ★New · 2 bedrooms · 6 beds · 1 bath',
#         317037207, ..., 357, 0, nan],
#        [985971781886468372,
#         'Rental unit in Antwerpen · ★New · 2 bedrooms · 6 beds · 1 bath',
#         165436938, ..., 357, 0, nan]], dtype=object)

# %%
df.describe()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  2.702000e+03  2.702000e+03                  0.0  2702.000000
# mean   4.306473e+17  2.011438e+08                  NaN    51.214709
# std    4.126397e+17  1.802781e+08                  NaN     0.013812
# min    5.090400e+04  2.318060e+05                  NaN    51.154816
# 25%    3.909367e+07  3.669645e+07                  NaN    51.208173
# 50%    5.899957e+17  1.492836e+08                  NaN    51.216830
# 75%    8.441347e+17  3.687807e+08                  NaN    51.221220
# max    9.859718e+17  5.382216e+08                  NaN    51.348090
#
#          longitude        price  minimum_nights  number_of_reviews  \
# count  2702.000000  2702.000000     2702.000000        2702.000000
# mean      4.413458   122.574759        6.460030          35.945596
# std       0.019357   225.742943       22.341359          67.592774
# min       4.290750    17.000000        1.000000           0.000000
# ...

# %%
#Transposing your data:
df.T
# Out:
#                                                                              0     \
# id                                                                          50904
# name                            Boutique hotel in Antwerp · ★5.0 · 1 bedroom ·...
# host_id                                                                    234077
# host_name                                                                   Karin
# neighbourhood_group                                                           NaN
# neighbourhood                                                  Historisch Centrum
# latitude                                                                51.218575
# longitude                                                                4.398631
# room_type                                                              Hotel room
# price                                                                         180
# ...

# %%
import plotly.express as px

# %%
long_df = df

fig = px.bar(long_df, x="room_type", color="room_type", title="AirBnB")
fig.show()
# Out:
# <div>                            <div id="9adf56e1-e984-453f-a0f9-14005b0fa2e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9adf56e1-e984-453f-a0f9-14005b0fa2e0")) {                    Plotly.newPlot(                        "9adf56e1-e984-453f-a0f9-14005b0fa2e0",                        [{"alignmentgroup":"True","hovertemplate":"room_type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Hotel room","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Hotel room","offsetgroup":"Hotel room","orientation":"v","showlegend":true,"textposition":"auto","x":["Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room"],"xaxis":"x","y":[1,1,1,1,1,1,1,1,1],"yaxis":"y","type":"bar"},{"alignment
# ...

# %%
long_df = df

fig = px.histogram(long_df, x="room_type", color="room_type", title="AirBnB")
fig.show()
# Out:
# <div>                            <div id="e58fb419-0045-4528-8703-7f85a6e5ad35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e58fb419-0045-4528-8703-7f85a6e5ad35")) {                    Plotly.newPlot(                        "e58fb419-0045-4528-8703-7f85a6e5ad35",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"room_type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Hotel room","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Hotel room","offsetgroup":"Hotel room","orientation":"v","showlegend":true,"x":["Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room","Hotel room"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":
# ...
